# %%
head = "python"
tail = "is fun"
head + tail
# Out:
# 'pythonis fun'

# %%
a="python"
a*3
# Out:
# 'pythonpythonpython'

# %%
a="Life is too short"
len(a)
# Out:
# 17

# %%
a[0]
# Out:
# 'L'

# %%
a[11]
# Out:
# ' '

# %%
a[-2]
# Out:
# 'r'

# %%
a= "Life is too short, you need python"
a[0:4]
# Out:
# 'Life'

# %%
a = 'Phython'

# %%
print(a) # a를 출력하다다
# Out:
# Phython

# %%
a # a 안에에 뭐가 있는지 보는것
# Out:
# 'Phython'

# %%
a ='python'
a
# Out:
# 'python'

# %%
a="python"
a
# Out:
# 'python'

# %%
a="pyt'hon"
a
# Out:
# "pyt'hon"

# %%
a='pyt"hon'
a
# Out:
# 'pyt"hon'

# %%
a="""pyt"hon"""
a
# Out:
# 'pyt"hon'

# %%
a = 'pyt\'hon'
a
# Out:
# "pyt'hon"

# %%
a = 'python is \n too fun'
print(a)
# Out:
# python is
#  too fun

# %%
a = """python is 

too 

fun

"""
print(a)
# Out:
# python is
#
# too
#
# fun

# %%
a= 'python'
a[0]
# Out:
# 'p'

# %%
a[3]
# Out:
# 'h'

# %%
a[-1]
# Out:
# 'n'

# %%
a[1:3]
# Out:
# 'yt'
