# %%
# 클래스 : 함수들을 저장하는 주머니
# 문자열 자료형 : 클래스
# 문자열.함수이름
'I eat {} apples'.format(5)
# Out:
# 'I eat 5 apples'

# %%
'I eat {} apples and {} oranges'.format(3,5)
# Out:
# 'I eat 3 apples and 5 oranges'

# %%
name = '이동욱'
age = 30

f"my name is {name} and my age is {age}"
# Out:
# 'my name is 이동욱 and my age is 30'

# %%
a='hello world'
a.count('o')
# Out:
# 2

# %%
a.find('l')
# Out:
# 2

# %%
a.find('z')
# Out:
# -1

# %%
'.'.join('abcd')
# Out:
# 'a.b.c.d'

# %%
'@@@@@'.join(['a','b','c','d'])
# Out:
# 'a@@@@@b@@@@@c@@@@@d'

# %%
a
# Out:
# 'hello world'

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
a.lower()
# Out:
# 'hello world'

# %%
a='  hello   '

# %%
a.lstrip()
# Out:
# 'hello   '

# %%
a.rstrip()
# Out:
# '  hello'

# %%
a
# Out:
# '  hello   '

# %%
a.replace('hello','python')
# Out:
# '  python   '

# %%
a='python:is:too:fun'
a
# Out:
# 'python:is:too:fun'

# %%
a.split()
# Out:
# ['python:is:too:fun']

# %%
a.split(':')
# Out:
# ['python', 'is', 'too', 'fun']
