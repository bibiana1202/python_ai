# %%
dic= {'이름':'장동건','나이':40,'성별':'남자','이상형':'고소영"'}
dic
# Out:
# {'나이': 40, '성별': '남자', '이름': '장동건', '이상형': '고소영"'}

# %%
# 왼쪽 : key
# 오른쪽 : value
# 딕셔너리는 무조건 Key 값으로 접근

dic['이름']
# Out:
# '장동건'

# %%
dic['가족']='Family'
dic
# Out:
# {'가족': 'Family', '나이': 40, '성별': '남자', '이름': '장동건', '이상형': '고소영"'}

# %%
dic['나이']=50
dic
# Out:
# {'가족': 'Family', '나이': 50, '성별': '남자', '이름': '장동건', '이상형': '고소영"'}

# %%
dic.keys()
# Out:
# dict_keys(['이름', '나이', '성별', '이상형', '가족'])

# %%
dic.values()
# Out:
# dict_values(['장동건', 50, '남자', '고소영"', 'Family'])

# %%
dic.items()
# Out:
# dict_items([('이름', '장동건'), ('나이', 50), ('성별', '남자'), ('이상형', '고소영"'), ('가족', 'Family')])

# %%
dic.clear()
dic
# Out:
# {}

# %%
a['이름']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f54dc346649a> in <module>()
# ----> 1 a['이름']
#
# NameError: name 'a' is not defined

# %%
dic.get('이름','없음')
# Out:
# '없음'

# %%
dic ={'이름':'장동건'}

# %%
dic.get('이름','없음')
# Out:
# '장동건'

# %%
'이름' in dic
# Out:
# True

# %%
'장동건' in dic
# Out:
# False

# %%
# 다음 빈칸을 완성하여 코드를 직접 실행해 보세요.
dic ={1: "Bitcoin",2:"Ethereum",3:"Litecoin"}
# 딕셔너리 쌍 추가, 삭제 합니다.
print(' 딕셔너리 쌍 {5:"XRP"} 추가 합니다')
dic[5]="XRP"
# Out:
#  딕셔너리 쌍 {5:"XRP"} 추가 합니다

# %%
dic[5]
# Out:
# 'XRP'

# %%
dic
# Out:
# {1: 'Bitcoin', 2: 'Ethereum', 3: 'Litecoin', 5: 'XRP'}

# %%
print('del 키워드를 사용해서 딕셔너리 쌍 1을 삭제합니다.')
del dic[1];
# Out:
# del 키워드를 사용해서 딕셔너리 쌍 1을 삭제합니다.

# %%
dic
# Out:
# {2: 'Ethereum', 3: 'Litecoin', 5: 'XRP'}

# %%
print('key 만을 모아서 객체 반환합니다')
dic.keys()
# Out:
# key 만을 모아서 객체 반환합니다
# dict_keys([2, 3, 5])

# %%
print('value 만을 모아서 객체 반환합니다.')
dic.values()
# Out:
# value 만을 모아서 객체 반환합니다.
# dict_values(['Ethereum', 'Litecoin', 'XRP'])

# %%
print('key 2가 딕셔너리 안에 있는지 조사합니다')
2 in dic
# Out:
# key 2가 딕셔너리 안에 있는지 조사합니다
# True

# %%
print("key 4 에 대응하는 Value 반환합니다.")
dic.get(4)
# Out:
# key 4 에 대응하는 Value 반환합니다.

# %%
print('key와 value 의 쌍을 튜플로 묶은 값을 모아서 객체로 반환합니다.')
dic.items()
# Out:
# key와 value 의 쌍을 튜플로 묶은 값을 모앗허 객체로 반환합니다.
# dict_items([(2, 'Ethereum'), (3, 'Litecoin'), (5, 'XRP')])
