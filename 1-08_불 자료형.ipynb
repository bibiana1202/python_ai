# %%
bool(5)
# Out:
# True

# %%
bool(-5)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool([3])
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool('1')
# Out:
# True

# %%
2>1
# Out:
# True

# %%
a = [1,2,True,False,'python']
for v in a:
  if bool(v) == True:
    print(f'{v} is True')
  else:
    print(f'{v} is False')
# Out:
# 1 is True
# 2 is True
# True is True
# False is False
# python is True

# %%
bool('python')
# Out:
# True

# %%
bool('')
# Out:
# False
