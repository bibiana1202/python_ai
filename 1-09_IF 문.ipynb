# %%
#if 조건 :

money = True

if money == True:
  print('taxi')
else:
  print('walk')
# Out:
# taxi

# %%
money = 2000

if money >= 3000:
  print('taxi')
else:
  print('walk')
# Out:
# walk

# %%
pocket = ['paper','cellphone']
pocket.extend(['card'])

if 'money' in pocket:
  print('taxi')
else:
  if 'card' in pocket:
    print('taxii')
  else:
    print('walk')
# Out:
# ['paper', 'cellphone', 'card']
# taxii

# %%
pocket = ['paper','cellphone','money']
pocket.extend(['card'])

if 'money' in pocket:
  print('taxi')
elif 'card' in pocket:
  print('taxii')
else:
  print('walk')
# Out:
# taxi

# %%
socre =50
message = 'good' if socre>= 60 else "bad"
message
# Out:
# 'bad'

# %%
age = int(input("현재 나이를 입력하세요 : "))
if age >=20:
  print("이미 성인이시 네요 !")
else:
  year = 20 -age
  print("성인이 되려면 %d년 이 남았습니다!"%year)
# Out:
# 현재 나이를 입력하세요 : 3
# 성인이 되려면 17년 이 남았습니다!
