# %%
print('hello')
# Out:
# hello

# %%
chr(91)
# Out:
# '['

# %%
chr(93)
# Out:
# ']'

# %%
hex(123)
# Out:
# '0x7b'

# %%
sorted({1,5,3})
# Out:
# [1, 3, 5]

# %%
tuple("abv")
# Out:
# ('a', 'b', 'v')

# %%
abs(-5)
# Out:
# 5

# %%
divmod(7,3)
# Out:
# (2, 1)

# %%
for n,i in enumerate(['one','two','three']):
  print(n,i)
# Out:
# 0 one
# 1 two
# 2 three

# %%
for n,i in enumerate({'one','two','three'}):
  print(n,i)
# Out:
# 0 one
# 1 three
# 2 two

# %%
eval('1+2')
# Out:
# 3

# %%
add= lambda a,b:a+b

# %%
add(3,4)
# Out:
# 7

# %%
list(filter(lambda i:i>0, [1,-3,2,0,-5,6]))
# Out:
# [1, 2, 6]

# %%
int('3')
# Out:
# 3

# %%
int(3.4)
# Out:
# 3

# %%
len('pytjon')
# Out:
# 6

# %%
len([1,2,3])
# Out:
# 3

# %%
list('pyton')
# Out:
# ['p', 'y', 't', 'o', 'n']

# %%
list(map(lambda i:i*3,[1,2,3,4]))
# Out:
# [3, 6, 9, 12]

# %%
max([1,2,3])
# Out:
# 3

# %%
min([1,2,3])
# Out:
# 1

# %%
pow(3,3)
# Out:
# 27

# %%
round(4.6)
# Out:
# 5

# %%
sorted([1,2,5,2])
# Out:
# [1, 2, 2, 5]

# %%
str(3)
# Out:
# '3'

# %%
sum([1,2,3,4,5])
# Out:
# 15

# %%
tuple('abc')
# Out:
# ('a', 'b', 'c')

# %%
a= [1,2,3]
b=[4,5,6]
for i,j in zip(a,b):
  print(i,j)
# Out:
# 1 4
# 2 5
# 3 6

# %%
a = ['1','4','3','2'] #->[1,4,3,2]
n = len(a)
print(n)
for i in range(0,n):
  c=eval(a[i])
  a[i]=c
a
# Out:
# [1, 4, 3, 2]
