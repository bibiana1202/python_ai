# %%
import pandas as pd

# %%
#csv파일 tsv파일
#.기준   탭기준

df= pd.read_csv("gapminder.tsv",sep='\t') #탭을 기준으로 데이터를 나누어
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-e7dddbd3d784> in <module>()
#       2 #.기준   탭기준
#       3
# ----> 4 df= pd.read_csv("gapminder.tsv",sep='\t') #탭을 기준으로 데이터를 나누어
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.head() #머리부분만 보겠다
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-020f9be5d984> in <module>()
# ----> 1 df.head() #머리부분만 보겠다
#
# NameError: name 'df' is not defined

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4add252522c8> in <module>()
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
type(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-16f65e8a7555> in <module>()
# ----> 1 type(df)
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-633337079cd0> in <module>()
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b666bf274d0a> in <module>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5cc0934cc03c> in <module>()
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df.info()

# %%
df['country']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7ef9c32ac548> in <module>()
# ----> 1 df['country']
#
# NameError: name 'df' is not defined

# %%
df[[]]
