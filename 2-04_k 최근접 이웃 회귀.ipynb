# %%
import numpy as np
import matplotlib.pyplot as plt



perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])

perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

plt.scatter(perch_length , perch_weight)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# 농어 데이터 75 훈련값 25 테스트 시험값에 들어감
train_input, test_input, train_target, test_target = train_test_split(perch_length,perch_weight)

train_input
# Out:
# array([39. , 43. , 19. , 40. , 42. , 22.5, 23. , 19.6, 30. , 32.8, 13.7,
#        25.6, 35. , 18.7,  8.4, 27.5, 34.5, 28. , 37. , 28.7, 21. , 26.5,
#        22. , 24.6, 22. , 24. , 36. , 27.5, 27.3, 43. , 22. , 40. , 27.5,
#        39. , 17.4, 22. , 39. , 22.7, 44. , 20. , 43.5, 22. ])

# %%
# 머신러닝 이차원 배열로
train_input = train_input.reshape(-1,1) # -1: 2차원 배열로 만든다 / 1: 가지고 있는 데이터 요인의 갯수
test_input = test_input.reshape(-1,1)

# %%
train_input
# Out:
# array([[39. ],
#        [43. ],
#        [19. ],
#        [40. ],
#        [42. ],
#        [22.5],
#        [23. ],
#        [19.6],
#        [30. ],
#        [32.8],
#        [13.7],
#        [25.6],
#        [35. ],
#        [18.7],
#        [ 8.4],
#        [27.5],
#        [34.5],
#        [28. ],
#        [37. ],
#        [28.7],
#        [21. ],
#        [26.5],
#        [22. ],
#        [24.6],
#        [22. ],
#        [24. ],
#        [36. ],
#        [27.5],
#        [27.3],
#        [43. ],
#        [22. ],
#        [40. ],
#        [27.5],
#        [39. ],
#        [17.4],
#        [22. ],
#        [39. ],
#        [22.7],
#        [44. ],
#        [20. ],
#        [43.5],
#        [22. ]])

# %%
from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor()
knr.fit(train_input,train_target)
# Out:
# KNeighborsRegressor()

# %%
knr.score(test_input,test_target) # 97퍼센트 정확도
# Out:
# 0.9704064435279639

# %%
knr.predict(test_input[:10]) # 생선 10마리의 대한 길이를 넣어 무게를 예측함
# Out:
# array([133. , 167.6, 167.6, 195.6,  79.6, 689.2,  69. , 824. , 824. ,
#        119. ])

# %%
test_target[:10] # 실제값
# Out:
# array([ 150.,  145.,  170.,  180.,  100.,  685.,   40.,  820., 1015.,
#         110.])

# %%
# 평균적으로 얼마나 틀렷는지
np.mean(abs(knr.predict(test_input[:10]) - test_target[:10]))
# Out:
# 31.520000000000003
