# %%
import pandas as pd

wine = pd.read_csv("https://bit.ly/wine-date")

data = wine[['alcohol','sugar','pH']].to_numpy()
target = wine['class'].to_numpy()

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data,target,test_size=0.2)

# %%
sub_input, val_input, sub_target,val_target = train_test_split(train_input,train_target,test_size=0.2)
# 훈련데이터의 80% =sub , 훈련데이터의 20% = val

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(sub_input,sub_target)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(val_input,val_target)
# Out:
# 0.8423076923076923

# %%
# 84% 정확도

# %%
# 교차검증  
from sklearn.model_selection import cross_validate

scores = cross_validate(dt,train_input,train_target)

# %%
scores
# Out:
# {'fit_time': array([0.01077867, 0.01021791, 0.01063752, 0.01094985, 0.01129508]),
#  'score_time': array([0.00133014, 0.00130582, 0.00129533, 0.00142765, 0.00137639]),
#  'test_score': array([0.87307692, 0.87115385, 0.85081809, 0.87006737, 0.87006737])}

# %%
# 훈련데이터의 5등분을 해서 1등분 쪽지시험 -> 5번의 쪽지시험 ->5개의 score

import numpy as np
np.mean(scores['test_score'])
# Out:
# 0.8670367216998593

# %%
# 5개의 검증값을 평균 86%
